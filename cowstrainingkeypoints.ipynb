# %%
# !pip install ultralytics

# %% [markdown]
# Importing objects

# %%
import cv2
from ultralytics import YOLO

# %%
det_model = YOLO('yolo11x.pt')

pose_model = YOLO('coco8-pose.yaml')
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 det_model = YOLO('yolo11x.pt')
# ----> 3 pose_model = YOLO('coco8-pose.yaml')
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# ...
